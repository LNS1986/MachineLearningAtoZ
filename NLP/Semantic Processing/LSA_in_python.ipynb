# %%
import nltk

from nltk.corpus import brown
#nltk.download()
#install 'brown' corpus

# %%
brown.words(categories='news')
# Out:
# ['The', 'Fulton', 'County', 'Grand', 'Jury', 'said', ...]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Read the data from the Brown corpus
data = ' '.join(brown.words()[:10000])

# %%
data[:10]
# Out:
# 'The Fulton'

# %%
TextCorpus = ['Seven continent planet',
'Five ocean planet', 
'Asia largest continent', 
'Pacific Ocean largest', 
'Ocean saline water']

text_tokens = [sent.split() for sent in TextCorpus]
print(text_tokens)
# Out:
# [['Seven', 'continent', 'planet'], ['Five', 'ocean', 'planet'], ['Asia', 'largest', 'continent'], ['Pacific', 'Ocean', 'largest'], ['Ocean', 'saline', 'water']]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
transformer = TfidfVectorizer()
tfidf = transformer.fit_transform(TextCorpus)

# %%
print(tfidf)
# (document number, term number)
# Out:
#   (0, 8)	0.6591180018251055
#   (0, 1)	0.5317722537280788
#   (0, 6)	0.5317722537280788
#   (1, 6)	0.5568161504458247
#   (1, 2)	0.6901592662889633
#   (1, 4)	0.46220770413113277
#   (2, 1)	0.5317722537280788
#   (2, 0)	0.6591180018251055
#   (2, 3)	0.5317722537280788
#   (3, 4)	0.46220770413113277
#   (3, 3)	0.5568161504458247
#   (3, 5)	0.6901592662889633
#   (4, 4)	0.42799292268317357
#   (4, 7)	0.6390704413963749
#   (4, 9)	0.6390704413963749

# %%
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(n_components = 3)
lsa = svd.fit_transform(tfidf)

# %%
lsa
# Out:
# array([[ 5.69995606e-01, -5.21026572e-01, -4.81700519e-01],
#        [ 6.29788097e-01,  2.47716942e-01, -5.41216825e-01],
#        [ 5.69995606e-01, -5.21026572e-01,  4.81700519e-01],
#        [ 6.29788097e-01,  2.47716942e-01,  5.41216825e-01],
#        [ 4.08516626e-01,  6.90173499e-01,  1.79742849e-15]])

# %%
text_tokens = [sent.split() for sent in data]
print(text_tokens)
# Out:
# [['T'], ['h'], ['e'], [], ['F'], ['u'], ['l'], ['t'], ['o'], ['n'], [], ['C'], ['o'], ['u'], ['n'], ['t'], ['y'], [], ['G'], ['r'], ['a'], ['n'], ['d'], [], ['J'], ['u'], ['r'], ['y'], [], ['s'], ['a'], ['i'], ['d'], [], ['F'], ['r'], ['i'], ['d'], ['a'], ['y'], [], ['a'], ['n'], [], ['i'], ['n'], ['v'], ['e'], ['s'], ['t'], ['i'], ['g'], ['a'], ['t'], ['i'], ['o'], ['n'], [], ['o'], ['f'], [], ['A'], ['t'], ['l'], ['a'], ['n'], ['t'], ['a'], ["'"], ['s'], [], ['r'], ['e'], ['c'], ['e'], ['n'], ['t'], [], ['p'], ['r'], ['i'], ['m'], ['a'], ['r'], ['y'], [], ['e'], ['l'], ['e'], ['c'], ['t'], ['i'], ['o'], ['n'], [], ['p'], ['r'], ['o'], ['d'], ['u'], ['c'], ['e'], ['d'], [], ['`'], ['`'], [], ['n'], ['o'], [], ['e'], ['v'], ['i'], ['d'], ['e'], ['n'], ['c'], ['e'], [], ["'"], ["'"], [], ['t'], ['h'], ['a'], ['t'], [], ['a'], ['n'], ['y'], [], ['i'], ['r'], ['r'], ['e'], ['g'], ['u'], ['l'], ['a'], ['r'], ['i'], ['t'], ['i'], ['e'], ['s'], [], ['t'], ['o'], ['o'], ['k'], [], ['p'], ['l'], ['a'], ['c'], ['e'], [], ['.'], [], ['T'], ['h'], ['e'], [], ['j'], ['u'], ['r'], ['y'], [], ['f'], ['u'], ['r'], ['t'], ['h'], ['e'], ['r'], [], ['s'], ['a'], ['i'], ['d'], [], ['i'], ['n'], [], ['t'], ['e'], ['r'], ['m'], ['-'], ['e'], ['n'], ['d'], [], ['p'], ['r'], ['e'], ['s'], ['e'], ['n'], ['t'], ['m'], ['e'], ['n'], ['t'], ['s'], [], ['t'], ['h'], ['a'], ['t'], [], ['t'], ['h'], ['e'], [], ['C'], ['i'], ['t'], ['y'], [], ['E'], ['x'], ['e'], ['c'], ['u'], ['t'], ['i'], ['v'], ['e'], [], ['C'], ['o'], ['m'], ['m'], ['i'], ['t'], ['t'], ['e'], ['e'], [], [','], [], ['w'], ['h'], ['i'], ['c'], ['h'], [], ['h'], ['a'], ['d'], [], ['o'], ['v'], ['e'], ['r'], ['-'], ['a'], ['l'], ['l'], [], ['c'], ['h'], ['a'], ['r'], ['g'], ['e'], [], ['o'], ['f'], [], ['t'], ['h'], ['e'], [], ['e'], ['l'], ['e'], ['c'], ['t'], ['i'], ['o'], ['n'], [], [','], [], ['`'], ['`'], [], ['d'], ['e'], ['s'], ['e'], ['r'], ['v'], ['e'], ['s'], [], ['t'], ['h'], ['e'], [], ['p'], ['r'], ['a'], ['i'], ['s'], ['e'], [], ['a'], ['n'], ['d'], [], ['t'], ['h'], ['a'], ['n'], ['k'], ['s'], [], ['o'], ['f'], [], ['t'], ['h'], ['e'], [], ['C'], ['i'], ['t'], ['y'], [], ['o'], ['f'], [], ['A'], ['t'], ['l'], ['a'], ['n'], ['t'], ['a'], [], ["'"], ["'"], [], ['f'], ['o'], ['r'], [], ['t'], ['h'], ['e'], [], ['m'], ['a'], ['n'], ['n'], ['e'], ['r'], [], ['i'], ['n'], [], ['w'], ['h'], ['i'], ['c'], ['h'], [], ['t'], ['h'], ['e'], [], ['e'], ['l'], ['e'], ['c'], ['t'], ['i'], ['o'], ['n'], [], ['w'], ['a'], ['s'], [], ['c'], ['o'], ['n'], ['d'], ['u'], ['c'], ['t'], ['e'], ['d'], [], ['.'], [], ['T'], ['h'], ['e'], [], ['S'], ['e'], ['p'], ['t'], ['e'], ['m'], ['b'], ['e'], ['r'], ['-'], ['O'], ['c'], ['t'], ['o'], ['b'], ['e'], ['r'], [], ['t'], ['e'], ['r'], ['m'], [], ['j'], ['u'], ['r'], ['y'], [], ['h'], ['a'], ['d'], [], ['b'], ['e'], ['e'], ['n'], [], ['c'], ['h'], ['a'], ['r'], ['g'], ['e'], ['d'], [], ['b'], ['y'], [], ['F'], ['u'], ['l'], ['t'], ['o'], ['n'], [], ['S'], ['u'], ['p'], ['e'], ['r'], ['i'], ['o'], ['r'], [], ['C'], ['o'], ['u'], ['r'], ['t'], [], ['J'], ['u'], ['d'], ['g'], ['e'], [], ['D'], ['u'], ['r'], ['w'], ['o'], ['o'], ['d'], [], ['P'], ['y'], ['e'], [], ['t'], ['o'], [], ['i'], ['n'], ['v'], ['e'], ['s'], ['t'], ['i'], ['g'], ['a'], ['t'], ['e'], [], ['r'], ['e'], ['p'], ['o'], ['r'], ['t'], ['s'], [], ['o'], ['f'], [], ['p'], ['o'], ['s'], ['s'], ['i'], ['b'], ['l'], ['e'], [], ['`'], ['`'], [], ['i'], ['r'], ['r'], ['e'], ['g'], ['u'], ['l'], ['a'], ['r'], ['i'], ['t'], ['i'], ['e'], ['s'], [], ["'"], ["'"], [], ['i'], ['n'], [], ['t'], ['h'], ['e'], [], ['h'], ['a'], ['r'], ['d'], ['-'], ['f'], ['o'], ['u'], ['g'], ['h'], ['t'], [], ['p'], ['r'], ['i'], ['m'], ['a'], ['r'], ['y'], [], ['w'], ['h'], ['i'], ['c'], ['h'], [], ['w'], ['a'], ['s'], [], ['w'], ['o'], ['n'], [], ['b'], ['y'], [], ['M'], ['a'], ['y'], ['o'], ['r'], ['-'], ['n'], ['o'], ['m'], ['i'], ['n'], ['a'], ['t'], ['e'], [], ['I'], ['v'], ['a'], ['n'], [], ['A'], ['l'], ['l'], [ ...
